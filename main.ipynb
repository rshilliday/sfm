# %%
import cv2
import pyntcloud
import random
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import bundle_adjustment as b
import matching as m
import reconstruction as r

# %matplotlib inline
mpl.rcParams['figure.dpi']= 200

# %%
### This cell does matching between images and outlier removal
n_imgs = 46 #46 if imgset = 'templering', 49 if imgset = 'Viking'

images, keypoints, descriptors, K = m.find_features(n_imgs, imgset='templering')

matcher = cv2.BFMatcher(cv2.NORM_L1)
matches = m.find_matches(matcher, keypoints, descriptors)
print('num_matches before outlier removal:', m.num_matches(matches))
m.print_num_img_pairs(matches)

matches = m.remove_outliers(matches, keypoints)
print("After outlier removal:")
m.print_num_img_pairs(matches)

img_adjacency, list_of_img_pairs = m.create_img_adjacency_matrix(n_imgs, matches)
# Out:
# num_matches before outlier removal: 59608
# Number of img pairs is 1034 out of possible 1035
# After outlier removal:
# Number of img pairs is 243 out of possible 1035

# %%
### This cell initializes the reconstruction
best_pair = r.best_img_pair(img_adjacency, matches, keypoints, K, top_x_perc=0.2)
R0, t0, R1, t1, points3d_with_views = r.initialize_reconstruction(keypoints, matches, K, best_pair[0], best_pair[1])

R_mats = {best_pair[0]: R0, best_pair[1]: R1}
t_vecs = {best_pair[0]: t0, best_pair[1]: t1}

resected_imgs = [best_pair[0], best_pair[1]] 
unresected_imgs = [i for i in range(len(images)) if i not in resected_imgs] 
print('initial image pair:', resected_imgs)
avg_err = 0
# Out:
# Triangulating: 436 points.
# initial image pair: [20, 23]

# %%
### This cell grows and refines the reconstruction 
BA_chkpts = [3,4,5,6] + [int(6*(1.34**i)) for i in range(25)]
while len(unresected_imgs) > 0:
    resected_idx, unresected_idx, prepend = r.next_img_pair_to_grow_reconstruction(n_imgs, best_pair, resected_imgs, unresected_imgs, img_adjacency)
    points3d_with_views, pts3d_for_pnp, pts2d_for_pnp, triangulation_status = r.get_correspondences_for_pnp(resected_idx, unresected_idx, points3d_with_views, matches, keypoints)
    if len(pts3d_for_pnp) < 12:
        print(f"{len(pts3d_for_pnp)} is too few correspondences for pnp. Skipping imgs resected:{resected_idx} and unresected:{unresected_idx}")
        print(f"Currently resected imgs: {resected_imgs}, unresected: {unresected_imgs}")
        continue

    R_res = R_mats[resected_idx]
    t_res = t_vecs[resected_idx]
    print(f"Unresected image: {unresected_idx}, resected: {resected_idx}")
    R_new, t_new = r.do_pnp(pts3d_for_pnp, pts2d_for_pnp, K)
    R_mats[unresected_idx] = R_new
    t_vecs[unresected_idx] = t_new
    if prepend == True: resected_imgs.insert(0, unresected_idx)
    else: resected_imgs.append(unresected_idx)
    unresected_imgs.remove(unresected_idx)
    pnp_errors, projpts, avg_err, perc_inliers = r.test_reproj_pnp_points(pts3d_for_pnp, pts2d_for_pnp, R_new, t_new, K)
    print(f"Average error of reprojecting points used to resect image {unresected_idx} back onto it is: {avg_err}")
    print(f"Fraction of Pnp inliers: {perc_inliers} num pts used in Pnp: {len(pnp_errors)}")
    
    if resected_idx < unresected_idx:
        kpts1, kpts2, kpts1_idxs, kpts2_idxs = r.get_aligned_kpts(resected_idx, unresected_idx, keypoints, matches, mask=triangulation_status)
        if np.sum(triangulation_status) > 0: #at least 1 point needs to be triangulated
            points3d_with_views, tri_errors, avg_tri_err_l, avg_tri_err_r = r.triangulate_points_and_reproject(R_res, t_res, R_new, t_new, K, points3d_with_views, resected_idx, unresected_idx, kpts1, kpts2, kpts1_idxs, kpts2_idxs, reproject=True)
    else:
        kpts1, kpts2, kpts1_idxs, kpts2_idxs = r.get_aligned_kpts(unresected_idx, resected_idx, keypoints, matches, mask=triangulation_status)
        if np.sum(triangulation_status) > 0: #at least 1 point needs to be triangulated
            points3d_with_views, tri_errors, avg_tri_err_l, avg_tri_err_r = r.triangulate_points_and_reproject(R_new, t_new, R_res, t_res, K, points3d_with_views, unresected_idx, resected_idx, kpts1, kpts2, kpts1_idxs, kpts2_idxs, reproject=True)
    
    if 0.8 < perc_inliers < 0.95 or 5 < avg_tri_err_l < 10 or 5 < avg_tri_err_r < 10: 
        #If % of inlers from Pnp is too low or triangulation error on either image is too high, bundle adjust
        points3d_with_views, R_mats, t_vecs = b.do_BA(points3d_with_views, R_mats, t_vecs, resected_imgs, keypoints, K, ftol=1e0)
        
    if len(resected_imgs) in BA_chkpts or len(unresected_imgs) == 0 or perc_inliers <= 0.8 or avg_tri_err_l >= 10 or avg_tri_err_r >= 10:
        #If % of inlers from Pnp is very low or triangulation error on either image is very high, bundle adjust with stricter tolerance
        points3d_with_views, R_mats, t_vecs = b.do_BA(points3d_with_views, R_mats, t_vecs, resected_imgs, keypoints, K, ftol=1e-1)
    
    av = 0
    for im in resected_imgs:
        p3d, p2d, avg_error, errors = r.get_reproj_errors(im, points3d_with_views, R_mats[im], t_vecs[im], K, keypoints, distCoeffs=np.array([]))
        print(f'Average reprojection error on image {im} is {avg_error} pixels')
        av += avg_error
    av = av/len(resected_imgs)
    print(f'Average reprojection error across all {len(resected_imgs)} resected images is {av} pixels')
    if len(resected_imgs) == 30: break
# Out:
# Unresected image: 25, resected: 24
# rvec: [[ 0.50766114]
#  [-2.10156888]
#  [ 2.29867579]]
#
# tvec: [[ 0.0434132 ]
#  [-1.80155935]
#  [ 0.5155942 ]]
# Average error of reprojecting points used to resect image 25 back onto it is: 0.7049232652085571
# Fraction of Pnp inliers: 1.0 num pts used in Pnp: 388
# Triangulating: 184 points.
# Average reprojection error for just-triangulated points on image 24 is: 6.068759133733349 pixels.
# Average reprojection error for just-triangulated points on image 25 is: 2.3039583504029206 pixels.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         1.6929e+04                                    9.41e+05
#        1              3         8.6274e+03      8.30e+03       4.84e-01       2.64e+05
# `ftol` termination condition is satisfied.
# Function evaluations 3, initial cost 1.6929e+04, final cost 8.6274e+03, first-order optimality 2.64e+05.
# Average reprojection error on image 22 is 0.5204822007721859 pixels
# Average reprojection error on image 21 is 0.24117516066841338 pixels
# Average reprojection error on image 20 is 0.17898800455508623 pixels
# Average reprojection error on image 23 is 0.476234309610596 pixels
# Average reprojection error on image 24 is 1.5025285172347158 pixels
# Average reprojection error on image 19 is 0.5065232718591007 pixels
# Average reprojection error on image 25 is 1.0033061182254415 pixels
# Average reprojection error across all 7 resected images is 0.6327482261322199 pixels
# Unresected image: 18, resected: 19
# rvec: [[ 0.23439619]
#  [-0.00803697]
#  [-0.04270545]]
#
# tvec: [[0.02732089]
#  [0.72987112]
#  [0.06652131]]
# Average error of reprojecting points used to resect image 18 back onto it is: 0.609686985644368
# Fraction of Pnp inliers: 0.9895833333333334 num pts used in Pnp: 384
# Triangulating: 222 points.
# Average reprojection error for just-triangulated points on image 18 is: 0.23518107372318686 pixels.
# Average reprojection error for just-triangulated points on image 19 is: 8.150196250178945 pixels.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         3.8819e+04                                    2.10e+06
#        1              2         2.4010e+04      1.48e+04       4.50e+00       1.88e+06
# `ftol` termination condition is satisfied.
# Function evaluations 2, initial cost 3.8819e+04, final cost 2.4010e+04, first-order optimality 1.88e+06.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         2.4010e+04                                    1.88e+06
#        1              2         8.3735e+03      1.56e+04       1.30e+00       1.09e+06
#        2              3         6.1040e+03      2.27e+03       4.39e-01       5.23e+04
#        3              4         6.0897e+03      1.43e+01       1.52e-01       3.17e+04
# `ftol` termination condition is satisfied.
# Function evaluations 4, initial cost 2.4010e+04, final cost 6.0897e+03, first-order optimality 3.17e+04.
# Average reprojection error on image 22 is 0.4795398240081006 pixels
# Average reprojection error on image 21 is 0.22383700476160406 pixels
# Average reprojection error on image 20 is 0.2400935318310137 pixels
# Average reprojection error on image 23 is 0.3545048490392695 pixels
# Average reprojection error on image 24 is 0.1488031359171657 pixels
# Average reprojection error on image 19 is 0.17915710764240522 pixels
# Average reprojection error on image 25 is 0.1319684158459681 pixels
# Average reprojection error on image 18 is 0.1868619744120473 pixels
# Average reprojection error across all 8 resected images is 0.24309573043219676 pixels
# Unresected image: 26, resected: 25
# rvec: [[-0.45190309]
#  [ 0.91902325]
#  [-2.98199671]]
#
# tvec: [[ 0.11483467]
#  [-2.1050705 ]
#  [ 0.77554911]]
# Average error of reprojecting points used to resect image 26 back onto it is: 0.4482231764909142
# Fraction of Pnp inliers: 0.9891304347826086 num pts used in Pnp: 368
# Triangulating: 170 points.
# Average reprojection error for just-triangulated points on image 25 is: 8.157911090278684 pixels.
# Average reprojection error for just-triangulated points on image 26 is: 7.716439894282427 pixels.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         5.0676e+04                                    8.32e+05
#        1              2         6.4571e+03      4.42e+04       6.61e-01       3.60e+04
# `ftol` termination condition is satisfied.
# Function evaluations 2, initial cost 5.0676e+04, final cost 6.4571e+03, first-order optimality 3.60e+04.
# Average reprojection error on image 22 is 0.4859708503672902 pixels
# Average reprojection error on image 21 is 0.22416783994188 pixels
# Average reprojection error on image 20 is 0.24790571049878535 pixels
# Average reprojection error on image 23 is 0.34766280590391174 pixels
# Average reprojection error on image 24 is 0.1589725002504631 pixels
# Average reprojection error on image 19 is 0.18190700938749504 pixels
# Average reprojection error on image 25 is 0.14121911147887692 pixels
# Average reprojection error on image 18 is 0.1874422652319784 pixels
# Average reprojection error on image 26 is 0.2181489566673722 pixels
# Average reprojection error across all 9 resected images is 0.24371078330311702 pixels
# Unresected image: 17, resected: 18
# rvec: [[ 0.3639808 ]
#  [-0.00385548]
#  [-0.05875055]]
#
# tvec: [[0.01276028]
#  [1.11167821]
#  [0.1988086 ]]
# Average error of reprojecting points used to resect image 17 back onto it is: 0.7645965743982077
# Fraction of Pnp inliers: 0.989769820971867 num pts used in Pnp: 391
# Triangulating: 145 points.
# Average reprojection error for just-triangulated points on image 17 is: 10.740403299977922 pixels.
# Average reprojection error for just-triangulated points on image 18 is: 11.634733160065487 pixels.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         8.7452e+04                                    9.76e+05
#        1              2         1.1154e+04      7.63e+04       2.11e+00       1.57e+06
#        2              3         7.6192e+03      3.53e+03       5.95e-01       3.67e+05
#        3              4         7.3334e+03      2.86e+02       2.61e-01       1.90e+05
# `ftol` termination condition is satisfied.
# Function evaluations 4, initial cost 8.7452e+04, final cost 7.3334e+03, first-order optimality 1.90e+05.
# Average reprojection error on image 22 is 0.4396853260872267 pixels
# Average reprojection error on image 21 is 0.19801759467058858 pixels
# Average reprojection error on image 20 is 0.2555159163884728 pixels
# Average reprojection error on image 23 is 0.2809454430089793 pixels
# Average reprojection error on image 24 is 0.15495089311143545 pixels
# Average reprojection error on image 19 is 0.2669501964745836 pixels
# Average reprojection error on image 25 is 0.1308028139552076 pixels
# Average reprojection error on image 18 is 0.4029865409635224 pixels
# Average reprojection error on image 26 is 0.1692836450403817 pixels
# Average reprojection error on image 17 is 0.2851434309187453 pixels
# Average reprojection error across all 10 resected images is 0.2584281800619143 pixels
# Unresected image: 27, resected: 26
# rvec: [[ 0.14237847]
#  [-1.35406382]
#  [ 2.91975306]]
#
# tvec: [[ 0.16040015]
#  [-2.38507332]
#  [ 1.06239096]]
# Average error of reprojecting points used to resect image 27 back onto it is: 0.38264224671936004
# Fraction of Pnp inliers: 0.9970059880239521 num pts used in Pnp: 334
# Triangulating: 177 points.
# Average reprojection error for just-triangulated points on image 26 is: 1.6762480710259748 pixels.
# Average reprojection error for just-triangulated points on image 27 is: 1.5670903233422804 pixels.
# Average reprojection error on image 22 is 0.4396853260872267 pixels
# Average reprojection error on image 21 is 0.19801759467058858 pixels
# Average reprojection error on image 20 is 0.2555159163884728 pixels
# Average reprojection error on image 23 is 0.2809454430089793 pixels
# Average reprojection error on image 24 is 0.15495089311143545 pixels
# Average reprojection error on image 19 is 0.2669501964745836 pixels
# Average reprojection error on image 25 is 0.1308028139552076 pixels
# Average reprojection error on image 18 is 0.4029865409635224 pixels
# Average reprojection error on image 26 is 0.5423363770675844 pixels
# Average reprojection error on image 17 is 0.2851434309187453 pixels
# Average reprojection error on image 27 is 0.7929109542776207 pixels
# Average reprojection error across all 11 resected images is 0.3409314079021788 pixels
# Unresected image: 16, resected: 17
# rvec: [[0.02223558]
#  [0.89711449]
#  [2.92244099]]
#
# tvec: [[0.04332104]
#  [1.52612557]
#  [0.37933195]]
# Average error of reprojecting points used to resect image 16 back onto it is: 0.7714300840380935
# Fraction of Pnp inliers: 0.9905362776025236 num pts used in Pnp: 317
# Triangulating: 174 points.
# Average reprojection error for just-triangulated points on image 16 is: 0.8507336397063667 pixels.
# Average reprojection error for just-triangulated points on image 17 is: 5.601516005877062 pixels.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         2.0770e+04                                    1.15e+06
#        1              2         9.9349e+03      1.08e+04       1.72e+00       7.00e+05
# `ftol` termination condition is satisfied.
# Function evaluations 2, initial cost 2.0770e+04, final cost 9.9349e+03, first-order optimality 7.00e+05.
# Average reprojection error on image 22 is 0.4503236479381985 pixels
# Average reprojection error on image 21 is 0.21118728108364268 pixels
# Average reprojection error on image 20 is 0.2791018830678146 pixels
# Average reprojection error on image 23 is 0.26920524265775436 pixels
# Average reprojection error on image 24 is 0.1657221009574476 pixels
# Average reprojection error on image 19 is 0.638239129926634 pixels
# Average reprojection error on image 25 is 0.1477203293078473 pixels
# Average reprojection error on image 18 is 0.5691057665216155 pixels
# Average reprojection error on image 26 is 0.13620598025765232 pixels
# Average reprojection error on image 17 is 0.8829454758133338 pixels
# Average reprojection error on image 27 is 0.2601625953767908 pixels
# Average reprojection error on image 16 is 0.3652052583292542 pixels
# Average reprojection error across all 12 resected images is 0.3645937242698322 pixels
# Unresected image: 28, resected: 27
# rvec: [[-0.17868015]
#  [-2.85964714]
#  [-1.39912133]]
#
# tvec: [[ 0.18314722]
#  [-2.63054089]
#  [ 1.38500981]]
# Average error of reprojecting points used to resect image 28 back onto it is: 0.34834735082732543
# Fraction of Pnp inliers: 1.0 num pts used in Pnp: 306
# Triangulating: 191 points.
# Average reprojection error for just-triangulated points on image 27 is: 1.8244732680234885 pixels.
# Average reprojection error for just-triangulated points on image 28 is: 1.2848304505923855 pixels.
# Average reprojection error on image 22 is 0.4503236479381985 pixels
# Average reprojection error on image 21 is 0.21118728108364268 pixels
# Average reprojection error on image 20 is 0.2791018830678146 pixels
# Average reprojection error on image 23 is 0.26920524265775436 pixels
# Average reprojection error on image 24 is 0.1657221009574476 pixels
# Average reprojection error on image 19 is 0.638239129926634 pixels
# Average reprojection error on image 25 is 0.1477203293078473 pixels
# Average reprojection error on image 18 is 0.5691057665216155 pixels
# Average reprojection error on image 26 is 0.13620598025765232 pixels
# Average reprojection error on image 17 is 0.8829454758133338 pixels
# Average reprojection error on image 27 is 0.6857798866524589 pixels
# Average reprojection error on image 16 is 0.3652052583292542 pixels
# Average reprojection error on image 28 is 0.7082432704553455 pixels
# Average reprojection error across all 13 resected images is 0.42376809638223073 pixels
# Unresected image: 15, resected: 16
# rvec: [[-0.00672599]
#  [ 0.99488169]
#  [ 2.87150186]]
#
# tvec: [[0.10663807]
#  [1.88610717]
#  [0.61034582]]
# Average error of reprojecting points used to resect image 15 back onto it is: 0.7527477398989713
# Fraction of Pnp inliers: 0.9935064935064936 num pts used in Pnp: 308
# Triangulating: 168 points.
# Average reprojection error for just-triangulated points on image 15 is: 1.2632210218649593 pixels.
# Average reprojection error for just-triangulated points on image 16 is: 2.633964038248285 pixels.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         1.4943e+04                                    7.00e+05
#        1              2         9.1803e+03      5.76e+03       9.84e-01       1.49e+05
#        2              3         9.0491e+03      1.31e+02       3.53e-01       1.17e+05
# `ftol` termination condition is satisfied.
# Function evaluations 3, initial cost 1.4943e+04, final cost 9.0491e+03, first-order optimality 1.17e+05.
# Average reprojection error on image 22 is 0.3987340420260805 pixels
# Average reprojection error on image 21 is 0.19303065778979042 pixels
# Average reprojection error on image 20 is 0.26622529941588813 pixels
# Average reprojection error on image 23 is 0.23692934045304614 pixels
# Average reprojection error on image 24 is 0.168324340251932 pixels
# Average reprojection error on image 19 is 0.36749834631738587 pixels
# Average reprojection error on image 25 is 0.15287291828608024 pixels
# Average reprojection error on image 18 is 0.2920439877086478 pixels
# Average reprojection error on image 26 is 0.1433146412596668 pixels
# Average reprojection error on image 17 is 0.17974078069128793 pixels
# Average reprojection error on image 27 is 0.11260352169587537 pixels
# Average reprojection error on image 16 is 0.14851534507740125 pixels
# Average reprojection error on image 28 is 0.14248177052880392 pixels
# Average reprojection error on image 15 is 0.19241305589788044 pixels
# Average reprojection error across all 14 resected images is 0.21390914624284046 pixels
# Unresected image: 29, resected: 28
# rvec: [[-0.98016842]
#  [-0.61051607]
#  [ 3.10161155]]
#
# tvec: [[ 0.21238493]
#  [-2.78131765]
#  [ 1.5522883 ]]
# Average error of reprojecting points used to resect image 29 back onto it is: 0.4193134455855049
# Fraction of Pnp inliers: 1.0 num pts used in Pnp: 315
# Triangulating: 233 points.
# Average reprojection error for just-triangulated points on image 28 is: 1.2723421723959447 pixels.
# Average reprojection error for just-triangulated points on image 29 is: 0.16112032073516805 pixels.
# Average reprojection error on image 22 is 0.3987340420260805 pixels
# Average reprojection error on image 21 is 0.19303065778979042 pixels
# Average reprojection error on image 20 is 0.26622529941588813 pixels
# Average reprojection error on image 23 is 0.23692934045304614 pixels
# Average reprojection error on image 24 is 0.168324340251932 pixels
# Average reprojection error on image 19 is 0.36749834631738587 pixels
# Average reprojection error on image 25 is 0.15287291828608024 pixels
# Average reprojection error on image 18 is 0.2920439877086478 pixels
# Average reprojection error on image 26 is 0.1433146412596668 pixels
# Average reprojection error on image 17 is 0.17974078069128793 pixels
# Average reprojection error on image 27 is 0.11260352169587537 pixels
# Average reprojection error on image 16 is 0.14851534507740125 pixels
# Average reprojection error on image 28 is 0.5031084467411929 pixels
# Average reprojection error on image 15 is 0.19241305589788044 pixels
# Average reprojection error on image 29 is 0.3095342519903797 pixels
# Average reprojection error across all 15 resected images is 0.2443259317068357 pixels
# Unresected image: 14, resected: 15
# rvec: [[ 0.8645873 ]
#  [-0.01862852]
#  [-0.12603632]]
#
# tvec: [[0.14735078]
#  [2.37798487]
#  [1.09118484]]
# Average error of reprojecting points used to resect image 14 back onto it is: 0.49456932394801106
# Fraction of Pnp inliers: 1.0 num pts used in Pnp: 198
# Triangulating: 92 points.
# Average reprojection error for just-triangulated points on image 14 is: 2.7665041357803553 pixels.
# Average reprojection error for just-triangulated points on image 15 is: 5.8185278286798905 pixels.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         1.5149e+04                                    2.82e+05
#        1              2         9.1407e+03      6.01e+03       9.23e-01       5.82e+04
# `ftol` termination condition is satisfied.
# Function evaluations 2, initial cost 1.5149e+04, final cost 9.1407e+03, first-order optimality 5.82e+04.
# Average reprojection error on image 22 is 0.3838363647551715 pixels
# Average reprojection error on image 21 is 0.19357493331989883 pixels
# Average reprojection error on image 20 is 0.267425351326115 pixels
# Average reprojection error on image 23 is 0.2351497947019424 pixels
# Average reprojection error on image 24 is 0.16792269845799251 pixels
# Average reprojection error on image 19 is 0.3241850056923351 pixels
# Average reprojection error on image 25 is 0.1567349785024088 pixels
# Average reprojection error on image 18 is 0.29243160168358956 pixels
# Average reprojection error on image 26 is 0.14672556440139883 pixels
# Average reprojection error on image 17 is 0.18315272162417626 pixels
# Average reprojection error on image 27 is 0.12020670871482017 pixels
# Average reprojection error on image 16 is 0.1511304368324598 pixels
# Average reprojection error on image 28 is 0.11925037636373875 pixels
# Average reprojection error on image 15 is 0.18053947017337724 pixels
# Average reprojection error on image 29 is 0.2242622414789627 pixels
# Average reprojection error on image 14 is 0.18289274333957034 pixels
# Average reprojection error across all 16 resected images is 0.20808881196049733 pixels
# Unresected image: 30, resected: 29
# rvec: [[-224.63737942]
#  [ 246.59591333]
#  [ -62.59257277]]
#
# tvec: [[ 0.26766877]
#  [-2.96294274]
#  [ 1.91192027]]
# Average error of reprojecting points used to resect image 30 back onto it is: 0.5679263030803356
# Fraction of Pnp inliers: 1.0 num pts used in Pnp: 307
# Triangulating: 143 points.
# Average reprojection error for just-triangulated points on image 29 is: 2.888277276969773 pixels.
# Average reprojection error for just-triangulated points on image 30 is: 0.32108702199883465 pixels.
# Average reprojection error on image 22 is 0.3838363647551715 pixels
# Average reprojection error on image 21 is 0.19357493331989883 pixels
# Average reprojection error on image 20 is 0.267425351326115 pixels
# Average reprojection error on image 23 is 0.2351497947019424 pixels
# Average reprojection error on image 24 is 0.16792269845799251 pixels
# Average reprojection error on image 19 is 0.3241850056923351 pixels
# Average reprojection error on image 25 is 0.1567349785024088 pixels
# Average reprojection error on image 18 is 0.29243160168358956 pixels
# Average reprojection error on image 26 is 0.14672556440139883 pixels
# Average reprojection error on image 17 is 0.18315272162417626 pixels
# Average reprojection error on image 27 is 0.12020670871482017 pixels
# Average reprojection error on image 16 is 0.1511304368324598 pixels
# Average reprojection error on image 28 is 0.11925037636373875 pixels
# Average reprojection error on image 15 is 0.18053947017337724 pixels
# Average reprojection error on image 29 is 0.7755707075790872 pixels
# Average reprojection error on image 14 is 0.18289274333957034 pixels
# Average reprojection error on image 30 is 0.48948626486998736 pixels
# Average reprojection error across all 17 resected images is 0.25707151307870996 pixels
# Unresected image: 13, resected: 14
# rvec: [[ 0.33852904]
#  [-2.19786684]
#  [ 2.19321724]]
#
# tvec: [[0.18215134]
#  [2.64430268]
#  [1.42729308]]
# Average error of reprojecting points used to resect image 13 back onto it is: 0.9229965156446996
# Fraction of Pnp inliers: 1.0 num pts used in Pnp: 165
# Triangulating: 174 points.
# Average reprojection error for just-triangulated points on image 13 is: 0.26329506451234097 pixels.
# Average reprojection error for just-triangulated points on image 14 is: 0.34868534677386104 pixels.
# Average reprojection error on image 22 is 0.3838363647551715 pixels
# Average reprojection error on image 21 is 0.19357493331989883 pixels
# Average reprojection error on image 20 is 0.267425351326115 pixels
# Average reprojection error on image 23 is 0.2351497947019424 pixels
# Average reprojection error on image 24 is 0.16792269845799251 pixels
# Average reprojection error on image 19 is 0.3241850056923351 pixels
# Average reprojection error on image 25 is 0.1567349785024088 pixels
# Average reprojection error on image 18 is 0.29243160168358956 pixels
# Average reprojection error on image 26 is 0.14672556440139883 pixels
# Average reprojection error on image 17 is 0.18315272162417626 pixels
# Average reprojection error on image 27 is 0.12020670871482017 pixels
# Average reprojection error on image 16 is 0.1511304368324598 pixels
# Average reprojection error on image 28 is 0.11925037636373875 pixels
# Average reprojection error on image 15 is 0.18053947017337724 pixels
# Average reprojection error on image 29 is 0.7755707075790872 pixels
# Average reprojection error on image 14 is 0.24506496962742935 pixels
# Average reprojection error on image 30 is 0.48948626486998736 pixels
# Average reprojection error on image 13 is 0.5850364305870773 pixels
# Average reprojection error across all 18 resected images is 0.278745798845167 pixels
# Unresected image: 31, resected: 30
# rvec: [[-1.28038236]
#  [-0.02067599]
#  [ 0.15838795]]
#
# tvec: [[ 0.30626841]
#  [-3.08619057]
#  [ 2.27442237]]
# Average error of reprojecting points used to resect image 31 back onto it is: 1.3621844701946857
# Fraction of Pnp inliers: 0.9924242424242424 num pts used in Pnp: 264
# Triangulating: 153 points.
# Average reprojection error for just-triangulated points on image 30 is: 0.21263002939678208 pixels.
# Average reprojection error for just-triangulated points on image 31 is: 0.21278563529099861 pixels.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         1.2361e+04                                    2.89e+05
#        1              2         9.3333e+03      3.03e+03       1.00e+00       3.30e+04
#        2              3         9.3211e+03      1.22e+01       8.03e-02       1.04e+03
# `ftol` termination condition is satisfied.
# Function evaluations 3, initial cost 1.2361e+04, final cost 9.3211e+03, first-order optimality 1.04e+03.
# Average reprojection error on image 22 is 0.38266310383661256 pixels
# Average reprojection error on image 21 is 0.19462108267437528 pixels
# Average reprojection error on image 20 is 0.26657868356259323 pixels
# Average reprojection error on image 23 is 0.23609711751857793 pixels
# Average reprojection error on image 24 is 0.17206988407300422 pixels
# Average reprojection error on image 19 is 0.3240013172458706 pixels
# Average reprojection error on image 25 is 0.16164875331532186 pixels
# Average reprojection error on image 18 is 0.29237111115501974 pixels
# Average reprojection error on image 26 is 0.15246777189920652 pixels
# Average reprojection error on image 17 is 0.18571121515227984 pixels
# Average reprojection error on image 27 is 0.13328257292977186 pixels
# Average reprojection error on image 16 is 0.1557359237620612 pixels
# Average reprojection error on image 28 is 0.14461053208169164 pixels
# Average reprojection error on image 15 is 0.17016649742693576 pixels
# Average reprojection error on image 29 is 0.1313498594718248 pixels
# Average reprojection error on image 14 is 0.12622455873965058 pixels
# Average reprojection error on image 30 is 0.13276995816174278 pixels
# Average reprojection error on image 13 is 0.14166705564610982 pixels
# Average reprojection error on image 31 is 0.1601232346557731 pixels
# Average reprojection error across all 19 resected images is 0.1928505385951802 pixels
# Unresected image: 12, resected: 13
# rvec: [[ 1.11614469]
#  [-0.01166087]
#  [-0.15322235]]
#
# tvec: [[0.24792825]
#  [2.84215025]
#  [1.80805229]]
# Average error of reprojecting points used to resect image 12 back onto it is: 0.41709280425151435
# Fraction of Pnp inliers: 1.0 num pts used in Pnp: 126
# Triangulating: 103 points.
# Average reprojection error for just-triangulated points on image 12 is: 0.8919742357915355 pixels.
# Average reprojection error for just-triangulated points on image 13 is: 2.8253730029208444 pixels.
# Average reprojection error on image 22 is 0.38266310383661256 pixels
# Average reprojection error on image 21 is 0.19462108267437528 pixels
# Average reprojection error on image 20 is 0.26657868356259323 pixels
# Average reprojection error on image 23 is 0.23609711751857793 pixels
# Average reprojection error on image 24 is 0.17206988407300422 pixels
# Average reprojection error on image 19 is 0.3240013172458706 pixels
# Average reprojection error on image 25 is 0.16164875331532186 pixels
# Average reprojection error on image 18 is 0.29237111115501974 pixels
# Average reprojection error on image 26 is 0.15246777189920652 pixels
# Average reprojection error on image 17 is 0.18571121515227984 pixels
# Average reprojection error on image 27 is 0.13328257292977186 pixels
# Average reprojection error on image 16 is 0.1557359237620612 pixels
# Average reprojection error on image 28 is 0.14461053208169164 pixels
# Average reprojection error on image 15 is 0.17016649742693576 pixels
# Average reprojection error on image 29 is 0.1313498594718248 pixels
# Average reprojection error on image 14 is 0.12622455873965058 pixels
# Average reprojection error on image 30 is 0.13276995816174278 pixels
# Average reprojection error on image 13 is 0.7684736601116378 pixels
# Average reprojection error on image 31 is 0.1601232346557731 pixels
# Average reprojection error on image 12 is 0.6311110181212577 pixels
# Average reprojection error across all 20 resected images is 0.24610389279476053 pixels
# Unresected image: 32, resected: 31
# rvec: [[-1.40473018]
#  [-0.00450688]
#  [ 0.20546192]]
#
# tvec: [[ 0.37044605]
#  [-3.18504252]
#  [ 2.69507528]]
# Average error of reprojecting points used to resect image 32 back onto it is: 0.5634552067912862
# Fraction of Pnp inliers: 1.0 num pts used in Pnp: 252
# Triangulating: 209 points.
# Average reprojection error for just-triangulated points on image 31 is: 2.1534628874693675 pixels.
# Average reprojection error for just-triangulated points on image 32 is: 0.18219373040366557 pixels.
# Average reprojection error on image 22 is 0.38266310383661256 pixels
# Average reprojection error on image 21 is 0.19462108267437528 pixels
# Average reprojection error on image 20 is 0.26657868356259323 pixels
# Average reprojection error on image 23 is 0.23609711751857793 pixels
# Average reprojection error on image 24 is 0.17206988407300422 pixels
# Average reprojection error on image 19 is 0.3240013172458706 pixels
# Average reprojection error on image 25 is 0.16164875331532186 pixels
# Average reprojection error on image 18 is 0.29237111115501974 pixels
# Average reprojection error on image 26 is 0.15246777189920652 pixels
# Average reprojection error on image 17 is 0.18571121515227984 pixels
# Average reprojection error on image 27 is 0.13328257292977186 pixels
# Average reprojection error on image 16 is 0.1557359237620612 pixels
# Average reprojection error on image 28 is 0.14461053208169164 pixels
# Average reprojection error on image 15 is 0.17016649742693576 pixels
# Average reprojection error on image 29 is 0.1313498594718248 pixels
# Average reprojection error on image 14 is 0.12622455873965058 pixels
# Average reprojection error on image 30 is 0.13276995816174278 pixels
# Average reprojection error on image 13 is 0.7684736601116378 pixels
# Average reprojection error on image 31 is 0.825631201809194 pixels
# Average reprojection error on image 12 is 0.6311110181212577 pixels
# Average reprojection error on image 32 is 0.39060564374354056 pixels
# Average reprojection error across all 21 resected images is 0.2846757841329606 pixels
# Unresected image: 11, resected: 12
# rvec: [[ 1.25347452]
#  [-0.01066654]
#  [-0.18293598]]
#
# tvec: [[0.32637766]
#  [2.98615666]
#  [2.14799688]]
# Average error of reprojecting points used to resect image 11 back onto it is: 1.481981181654146
# Fraction of Pnp inliers: 1.0 num pts used in Pnp: 71
# Triangulating: 128 points.
# Average reprojection error for just-triangulated points on image 11 is: 0.38045077461109367 pixels.
# Average reprojection error for just-triangulated points on image 12 is: 0.36729486661168453 pixels.
# Average reprojection error on image 22 is 0.38266310383661256 pixels
# Average reprojection error on image 21 is 0.19462108267437528 pixels
# Average reprojection error on image 20 is 0.26657868356259323 pixels
# Average reprojection error on image 23 is 0.23609711751857793 pixels
# Average reprojection error on image 24 is 0.17206988407300422 pixels
# Average reprojection error on image 19 is 0.3240013172458706 pixels
# Average reprojection error on image 25 is 0.16164875331532186 pixels
# Average reprojection error on image 18 is 0.29237111115501974 pixels
# Average reprojection error on image 26 is 0.15246777189920652 pixels
# Average reprojection error on image 17 is 0.18571121515227984 pixels
# Average reprojection error on image 27 is 0.13328257292977186 pixels
# Average reprojection error on image 16 is 0.1557359237620612 pixels
# Average reprojection error on image 28 is 0.14461053208169164 pixels
# Average reprojection error on image 15 is 0.17016649742693576 pixels
# Average reprojection error on image 29 is 0.1313498594718248 pixels
# Average reprojection error on image 14 is 0.12622455873965058 pixels
# Average reprojection error on image 30 is 0.13276995816174278 pixels
# Average reprojection error on image 13 is 0.7684736601116378 pixels
# Average reprojection error on image 31 is 0.825631201809194 pixels
# Average reprojection error on image 12 is 0.5359885747600595 pixels
# Average reprojection error on image 32 is 0.39060564374354056 pixels
# Average reprojection error on image 11 is 0.7734591107922919 pixels
# Average reprojection error across all 22 resected images is 0.3025694606465121 pixels
# Unresected image: 33, resected: 32
# rvec: [[-1.48695502]
#  [ 0.02237666]
#  [ 0.26146418]]
#
# tvec: [[ 0.41585629]
#  [-3.22698933]
#  [ 3.05649414]]
# Average error of reprojecting points used to resect image 33 back onto it is: 1.3821083931370597
# Fraction of Pnp inliers: 0.9960159362549801 num pts used in Pnp: 251
# Triangulating: 122 points.
# Average reprojection error for just-triangulated points on image 32 is: 0.2890787717775695 pixels.
# Average reprojection error for just-triangulated points on image 33 is: 0.29099057356349184 pixels.
# Average reprojection error on image 22 is 0.38266310383661256 pixels
# Average reprojection error on image 21 is 0.19462108267437528 pixels
# Average reprojection error on image 20 is 0.26657868356259323 pixels
# Average reprojection error on image 23 is 0.23609711751857793 pixels
# Average reprojection error on image 24 is 0.17206988407300422 pixels
# Average reprojection error on image 19 is 0.3240013172458706 pixels
# Average reprojection error on image 25 is 0.16164875331532186 pixels
# Average reprojection error on image 18 is 0.29237111115501974 pixels
# Average reprojection error on image 26 is 0.15246777189920652 pixels
# Average reprojection error on image 17 is 0.18571121515227984 pixels
# Average reprojection error on image 27 is 0.13328257292977186 pixels
# Average reprojection error on image 16 is 0.1557359237620612 pixels
# Average reprojection error on image 28 is 0.14461053208169164 pixels
# Average reprojection error on image 15 is 0.17016649742693576 pixels
# Average reprojection error on image 29 is 0.1313498594718248 pixels
# Average reprojection error on image 14 is 0.12622455873965058 pixels
# Average reprojection error on image 30 is 0.13276995816174278 pixels
# Average reprojection error on image 13 is 0.7684736601116378 pixels
# Average reprojection error on image 31 is 0.825631201809194 pixels
# Average reprojection error on image 12 is 0.5359885747600595 pixels
# Average reprojection error on image 32 is 0.36935988322922075 pixels
# Average reprojection error on image 11 is 0.7734591107922919 pixels
# Average reprojection error on image 33 is 1.02522803391996 pixels
# Average reprojection error across all 23 resected images is 0.33306566989690894 pixels
# Unresected image: 10, resected: 11
# rvec: [[ 1882.2191142 ]
#  [-3782.7312407 ]
#  [-5481.41061078]]
#
# tvec: [[0.39829493]
#  [3.09102697]
#  [2.55867544]]
# Average error of reprojecting points used to resect image 10 back onto it is: 1.285511550646719
# Fraction of Pnp inliers: 0.95 num pts used in Pnp: 100
# Triangulating: 94 points.
# Average reprojection error for just-triangulated points on image 10 is: 0.14919176040639176 pixels.
# Average reprojection error for just-triangulated points on image 11 is: 0.1521113276719971 pixels.
# Average reprojection error on image 22 is 0.38266310383661256 pixels
# Average reprojection error on image 21 is 0.19462108267437528 pixels
# Average reprojection error on image 20 is 0.26657868356259323 pixels
# Average reprojection error on image 23 is 0.23609711751857793 pixels
# Average reprojection error on image 24 is 0.17206988407300422 pixels
# Average reprojection error on image 19 is 0.3240013172458706 pixels
# Average reprojection error on image 25 is 0.16164875331532186 pixels
# Average reprojection error on image 18 is 0.29237111115501974 pixels
# Average reprojection error on image 26 is 0.15246777189920652 pixels
# Average reprojection error on image 17 is 0.18571121515227984 pixels
# Average reprojection error on image 27 is 0.13328257292977186 pixels
# Average reprojection error on image 16 is 0.1557359237620612 pixels
# Average reprojection error on image 28 is 0.14461053208169164 pixels
# Average reprojection error on image 15 is 0.17016649742693576 pixels
# Average reprojection error on image 29 is 0.1313498594718248 pixels
# Average reprojection error on image 14 is 0.12622455873965058 pixels
# Average reprojection error on image 30 is 0.13276995816174278 pixels
# Average reprojection error on image 13 is 0.7684736601116378 pixels
# Average reprojection error on image 31 is 0.825631201809194 pixels
# Average reprojection error on image 12 is 0.5359885747600595 pixels
# Average reprojection error on image 32 is 0.36935988322922075 pixels
# Average reprojection error on image 11 is 0.5741188663782724 pixels
# Average reprojection error on image 33 is 1.02522803391996 pixels
# Average reprojection error on image 10 is 0.7345720763139041 pixels
# Average reprojection error across all 24 resected images is 0.3414892599803663 pixels
# Unresected image: 34, resected: 33
# rvec: [[-1.59173869]
#  [-0.0048068 ]
#  [ 0.2388916 ]]
#
# tvec: [[ 0.45090907]
#  [-3.23939825]
#  [ 3.29448184]]
# Average error of reprojecting points used to resect image 34 back onto it is: 1.680922767179613
# Fraction of Pnp inliers: 0.9704797047970479 num pts used in Pnp: 271
# Triangulating: 140 points.
# Average reprojection error for just-triangulated points on image 33 is: 0.6213353839252147 pixels.
# Average reprojection error for just-triangulated points on image 34 is: 0.6228455222598805 pixels.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         1.5131e+04                                    3.70e+05
#        1              3         1.1732e+04      3.40e+03       3.88e-01       1.27e+05
#        2              4         9.6077e+03      2.12e+03       7.48e-01       4.23e+04
#        3              6         9.5970e+03      1.08e+01       1.33e-01       6.53e+04
# `ftol` termination condition is satisfied.
# Function evaluations 6, initial cost 1.5131e+04, final cost 9.5970e+03, first-order optimality 6.53e+04.
# Average reprojection error on image 22 is 0.3824692952428192 pixels
# Average reprojection error on image 21 is 0.19495101198163267 pixels
# Average reprojection error on image 20 is 0.268477757307908 pixels
# Average reprojection error on image 23 is 0.23618173767739783 pixels
# Average reprojection error on image 24 is 0.1725856220765769 pixels
# Average reprojection error on image 19 is 0.3254011900362519 pixels
# Average reprojection error on image 25 is 0.16345417959913294 pixels
# Average reprojection error on image 18 is 0.29321330021708564 pixels
# Average reprojection error on image 26 is 0.15575825755779704 pixels
# Average reprojection error on image 17 is 0.18790113516614038 pixels
# Average reprojection error on image 27 is 0.14113946184251636 pixels
# Average reprojection error on image 16 is 0.16006596322760536 pixels
# Average reprojection error on image 28 is 0.15739553956595315 pixels
# Average reprojection error on image 15 is 0.17701344738869246 pixels
# Average reprojection error on image 29 is 0.14741425597689378 pixels
# Average reprojection error on image 14 is 0.14486418967893355 pixels
# Average reprojection error on image 30 is 0.16379831772293507 pixels
# Average reprojection error on image 13 is 0.15735045376321005 pixels
# Average reprojection error on image 31 is 0.1489785924633968 pixels
# Average reprojection error on image 12 is 0.16049501009035227 pixels
# Average reprojection error on image 32 is 0.14402683429523078 pixels
# Average reprojection error on image 11 is 0.11297105517077824 pixels
# Average reprojection error on image 33 is 0.12474588930162973 pixels
# Average reprojection error on image 10 is 0.11658161590516758 pixels
# Average reprojection error on image 34 is 0.29199178305972695 pixels
# Average reprojection error across all 25 resected images is 0.18916903585263056 pixels
# Unresected image: 9, resected: 10
# rvec: [[0.16231767]
#  [2.02355744]
#  [2.21527702]]
#
# tvec: [[0.44964469]
#  [3.14570113]
#  [2.95370165]]
# Average error of reprojecting points used to resect image 9 back onto it is: 0.36603166521965164
# Fraction of Pnp inliers: 1.0 num pts used in Pnp: 133
# Triangulating: 107 points.
# Average reprojection error for just-triangulated points on image 9 is: 1.222628755116427 pixels.
# Average reprojection error for just-triangulated points on image 10 is: 9.679151237559 pixels.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         2.6572e+04                                    8.50e+05
#        1              2         1.4885e+04      1.17e+04       3.47e+00       9.55e+05
# `ftol` termination condition is satisfied.
# Function evaluations 2, initial cost 2.6572e+04, final cost 1.4885e+04, first-order optimality 9.55e+05.
# Average reprojection error on image 22 is 0.38232181087033634 pixels
# Average reprojection error on image 21 is 0.193953525918906 pixels
# Average reprojection error on image 20 is 0.2657910565912789 pixels
# Average reprojection error on image 23 is 0.23595767324357025 pixels
# Average reprojection error on image 24 is 0.172648112308608 pixels
# Average reprojection error on image 19 is 0.32519026043145033 pixels
# Average reprojection error on image 25 is 0.16290589486290102 pixels
# Average reprojection error on image 18 is 0.29296263056989735 pixels
# Average reprojection error on image 26 is 0.1548549813239592 pixels
# Average reprojection error on image 17 is 0.18737456041656558 pixels
# Average reprojection error on image 27 is 0.13938707934288702 pixels
# Average reprojection error on image 16 is 0.15934262562003831 pixels
# Average reprojection error on image 28 is 0.15552212853305236 pixels
# Average reprojection error on image 15 is 0.17500191120050523 pixels
# Average reprojection error on image 29 is 0.144671843012863 pixels
# Average reprojection error on image 14 is 0.14056848609405118 pixels
# Average reprojection error on image 30 is 0.15710834661293854 pixels
# Average reprojection error on image 13 is 0.13939758615892694 pixels
# Average reprojection error on image 31 is 0.13468562077304252 pixels
# Average reprojection error on image 12 is 0.14178714995705266 pixels
# Average reprojection error on image 32 is 0.11675502650638588 pixels
# Average reprojection error on image 11 is 0.12330961741041171 pixels
# Average reprojection error on image 33 is 0.3427018410432979 pixels
# Average reprojection error on image 10 is 0.45695177971205425 pixels
# Average reprojection error on image 34 is 3.0206760850054293 pixels
# Average reprojection error on image 9 is 0.3632910916185761 pixels
# Average reprojection error across all 26 resected images is 0.3186584125053456 pixels
# Unresected image: 35, resected: 34
# rvec: [[-1.85968654]
#  [ 0.03507201]
#  [ 0.32400175]]
#
# tvec: [[ 0.58203708]
#  [-3.09324325]
#  [ 4.03379231]]
# Average error of reprojecting points used to resect image 35 back onto it is: 0.35603508768684083
# Fraction of Pnp inliers: 1.0 num pts used in Pnp: 296
# Triangulating: 149 points.
# Average reprojection error for just-triangulated points on image 34 is: 6.524394093099689 pixels.
# Average reprojection error for just-triangulated points on image 35 is: 6.70343448662153 pixels.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         3.3318e+04                                    1.92e+06
#        1              2         9.8018e+03      2.35e+04       1.32e+00       1.26e+05
# `ftol` termination condition is satisfied.
# Function evaluations 2, initial cost 3.3318e+04, final cost 9.8018e+03, first-order optimality 1.26e+05.
# Average reprojection error on image 22 is 0.3812722299172846 pixels
# Average reprojection error on image 21 is 0.19339270826388955 pixels
# Average reprojection error on image 20 is 0.26437459865498103 pixels
# Average reprojection error on image 23 is 0.23638880290807002 pixels
# Average reprojection error on image 24 is 0.1722030981721108 pixels
# Average reprojection error on image 19 is 0.32522868589905785 pixels
# Average reprojection error on image 25 is 0.1624890076487987 pixels
# Average reprojection error on image 18 is 0.29322918549964716 pixels
# Average reprojection error on image 26 is 0.1559059161881221 pixels
# Average reprojection error on image 17 is 0.18747542961186167 pixels
# Average reprojection error on image 27 is 0.14123736964680544 pixels
# Average reprojection error on image 16 is 0.15923498904679825 pixels
# Average reprojection error on image 28 is 0.15743729508243723 pixels
# Average reprojection error on image 15 is 0.17496215984868135 pixels
# Average reprojection error on image 29 is 0.14675077986548965 pixels
# Average reprojection error on image 14 is 0.14058275112854354 pixels
# Average reprojection error on image 30 is 0.16184468937953214 pixels
# Average reprojection error on image 13 is 0.13923675835878271 pixels
# Average reprojection error on image 31 is 0.14282322416501053 pixels
# Average reprojection error on image 12 is 0.1407760883854536 pixels
# Average reprojection error on image 32 is 0.12136039183624062 pixels
# Average reprojection error on image 11 is 0.11543124951643913 pixels
# Average reprojection error on image 33 is 0.1121976852448596 pixels
# Average reprojection error on image 10 is 0.11753500854006768 pixels
# Average reprojection error on image 34 is 0.2269006845392072 pixels
# Average reprojection error on image 9 is 0.11589567031838174 pixels
# Average reprojection error on image 35 is 0.4906039046353483 pixels
# Average reprojection error across all 27 resected images is 0.1917322356408111 pixels
# Unresected image: 8, resected: 9
# rvec: [[ 1.62841645]
#  [-0.01361358]
#  [-0.24138299]]
#
# tvec: [[0.44292501]
#  [3.14748134]
#  [3.43023116]]
# Average error of reprojecting points used to resect image 8 back onto it is: 1.2639744029126183
# Fraction of Pnp inliers: 1.0 num pts used in Pnp: 149
# Triangulating: 157 points.
# Average reprojection error for just-triangulated points on image 8 is: 1.4129310633507646 pixels.
# Average reprojection error for just-triangulated points on image 9 is: 15.297754297119939 pixels.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         6.9789e+04                                    1.83e+06
#        1              2         1.0539e+04      5.93e+04       5.83e+00       2.49e+05
#        2              3         9.6427e+03      8.96e+02       5.01e-01       8.97e+03
# `ftol` termination condition is satisfied.
# Function evaluations 3, initial cost 6.9789e+04, final cost 9.6427e+03, first-order optimality 8.97e+03.
# Average reprojection error on image 22 is 0.3812864511435987 pixels
# Average reprojection error on image 21 is 0.19339335362957502 pixels
# Average reprojection error on image 20 is 0.2631688260995267 pixels
# Average reprojection error on image 23 is 0.23621583276714392 pixels
# Average reprojection error on image 24 is 0.17212609139168583 pixels
# Average reprojection error on image 19 is 0.3256081334102725 pixels
# Average reprojection error on image 25 is 0.1628129609437705 pixels
# Average reprojection error on image 18 is 0.2935893784139251 pixels
# Average reprojection error on image 26 is 0.15618741298477462 pixels
# Average reprojection error on image 17 is 0.18766553116800755 pixels
# Average reprojection error on image 27 is 0.1413768508391311 pixels
# Average reprojection error on image 16 is 0.15954237634650015 pixels
# Average reprojection error on image 28 is 0.1570323570278647 pixels
# Average reprojection error on image 15 is 0.17524519707343336 pixels
# Average reprojection error on image 29 is 0.14681641967353926 pixels
# Average reprojection error on image 14 is 0.14371175358142863 pixels
# Average reprojection error on image 30 is 0.16120404407319594 pixels
# Average reprojection error on image 13 is 0.14099490882817806 pixels
# Average reprojection error on image 31 is 0.14194798191983646 pixels
# Average reprojection error on image 12 is 0.14627303099199573 pixels
# Average reprojection error on image 32 is 0.12073153268654024 pixels
# Average reprojection error on image 11 is 0.1227992299403102 pixels
# Average reprojection error on image 33 is 0.11013150946542494 pixels
# Average reprojection error on image 10 is 0.1396662934923137 pixels
# Average reprojection error on image 34 is 0.09957671833746498 pixels
# Average reprojection error on image 9 is 0.10314665958180447 pixels
# Average reprojection error on image 35 is 0.1267859071245942 pixels
# Average reprojection error on image 8 is 0.136220821482865 pixels
# Average reprojection error across all 28 resected images is 0.17304491301495362 pixels
# Unresected image: 36, resected: 35
# rvec: [[-1.93865076]
#  [ 0.01456945]
#  [ 0.3077692 ]]
#
# tvec: [[ 0.70086145]
#  [-2.98313399]
#  [ 4.29855446]]
# Average error of reprojecting points used to resect image 36 back onto it is: 1.2157546675421844
# Fraction of Pnp inliers: 0.9937888198757764 num pts used in Pnp: 322
# Triangulating: 143 points.
# Average reprojection error for just-triangulated points on image 35 is: 10.714102008497148 pixels.
# Average reprojection error for just-triangulated points on image 36 is: 7.311287044064802 pixels.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         5.2931e+04                                    1.33e+06
#        1              2         1.5967e+04      3.70e+04       2.42e+00       1.09e+06
# `ftol` termination condition is satisfied.
# Function evaluations 2, initial cost 5.2931e+04, final cost 1.5967e+04, first-order optimality 1.09e+06.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         1.5967e+04                                    1.09e+06
#        1              2         1.0071e+04      5.90e+03       9.86e-01       1.22e+04
#        2              3         1.0003e+04      6.75e+01       3.57e-01       1.11e+04
# `ftol` termination condition is satisfied.
# Function evaluations 3, initial cost 1.5967e+04, final cost 1.0003e+04, first-order optimality 1.11e+04.
# Average reprojection error on image 22 is 0.3810261205170952 pixels
# Average reprojection error on image 21 is 0.1929334222532848 pixels
# Average reprojection error on image 20 is 0.26140818554799444 pixels
# Average reprojection error on image 23 is 0.23616249122695782 pixels
# Average reprojection error on image 24 is 0.1720285433891494 pixels
# Average reprojection error on image 19 is 0.325642559959216 pixels
# Average reprojection error on image 25 is 0.1625927477542533 pixels
# Average reprojection error on image 18 is 0.29356113401989226 pixels
# Average reprojection error on image 26 is 0.15643092905113376 pixels
# Average reprojection error on image 17 is 0.1874725143837101 pixels
# Average reprojection error on image 27 is 0.14239398608936193 pixels
# Average reprojection error on image 16 is 0.1591971592926707 pixels
# Average reprojection error on image 28 is 0.15884494405742527 pixels
# Average reprojection error on image 15 is 0.1750962226593357 pixels
# Average reprojection error on image 29 is 0.1490887100727287 pixels
# Average reprojection error on image 14 is 0.14312678994913855 pixels
# Average reprojection error on image 30 is 0.16429009454930066 pixels
# Average reprojection error on image 13 is 0.14061053268242674 pixels
# Average reprojection error on image 31 is 0.14855194581684608 pixels
# Average reprojection error on image 12 is 0.1463348547725874 pixels
# Average reprojection error on image 32 is 0.12880969665823822 pixels
# Average reprojection error on image 11 is 0.1227204742103847 pixels
# Average reprojection error on image 33 is 0.1287219316974244 pixels
# Average reprojection error on image 10 is 0.139449497865321 pixels
# Average reprojection error on image 34 is 0.14957165022869257 pixels
# Average reprojection error on image 9 is 0.09951812502721763 pixels
# Average reprojection error on image 35 is 0.32284591430774795 pixels
# Average reprojection error on image 8 is 0.10868451205486244 pixels
# Average reprojection error on image 36 is 0.3302748674111518 pixels
# Average reprojection error across all 29 resected images is 0.18715139853467413 pixels
# Unresected image: 7, resected: 8
# rvec: [[ 1.69689671]
#  [-0.00907849]
#  [-0.25784727]]
#
# tvec: [[0.54150648]
#  [3.16307834]
#  [3.60394796]]
# Average error of reprojecting points used to resect image 7 back onto it is: 0.3500322449234162
# Fraction of Pnp inliers: 1.0 num pts used in Pnp: 234
# Triangulating: 243 points.
# Average reprojection error for just-triangulated points on image 7 is: 22.94070173618651 pixels.
# Average reprojection error for just-triangulated points on image 8 is: 105.49318476430507 pixels.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         3.9651e+06                                    4.94e+07
#        1              2         4.5281e+05      3.51e+06       6.92e+00       1.18e+07
#        2              3         6.2385e+04      3.90e+05       1.54e+01       2.35e+06
#        3              4         1.0763e+04      5.16e+04       7.30e+00       2.19e+05
#        4              5         1.0115e+04      6.48e+02       3.38e-01       3.31e+03
# `ftol` termination condition is satisfied.
# Function evaluations 5, initial cost 3.9651e+06, final cost 1.0115e+04, first-order optimality 3.31e+03.
# Average reprojection error on image 22 is 0.3790215837739872 pixels
# Average reprojection error on image 21 is 0.19148355293860925 pixels
# Average reprojection error on image 20 is 0.25169460367106017 pixels
# Average reprojection error on image 23 is 0.23490509130074005 pixels
# Average reprojection error on image 24 is 0.17232626522770708 pixels
# Average reprojection error on image 19 is 0.3275647758634737 pixels
# Average reprojection error on image 25 is 0.16260810210306864 pixels
# Average reprojection error on image 18 is 0.29500774615951203 pixels
# Average reprojection error on image 26 is 0.1561563802175959 pixels
# Average reprojection error on image 17 is 0.1880293621632955 pixels
# Average reprojection error on image 27 is 0.14214179410124456 pixels
# Average reprojection error on image 16 is 0.1589189449265632 pixels
# Average reprojection error on image 28 is 0.1587268236908216 pixels
# Average reprojection error on image 15 is 0.1749285195682732 pixels
# Average reprojection error on image 29 is 0.1489939534584021 pixels
# Average reprojection error on image 14 is 0.14400373015081142 pixels
# Average reprojection error on image 30 is 0.16422268669501183 pixels
# Average reprojection error on image 13 is 0.14134608119919542 pixels
# Average reprojection error on image 31 is 0.14849898119055077 pixels
# Average reprojection error on image 12 is 0.14914103656700944 pixels
# Average reprojection error on image 32 is 0.12868403971152612 pixels
# Average reprojection error on image 11 is 0.12765883477057005 pixels
# Average reprojection error on image 33 is 0.12736935299961852 pixels
# Average reprojection error on image 10 is 0.1523782749248624 pixels
# Average reprojection error on image 34 is 0.14107200609192924 pixels
# Average reprojection error on image 9 is 0.12405853584833706 pixels
# Average reprojection error on image 35 is 0.31547538871930436 pixels
# Average reprojection error on image 8 is 0.11983368407365605 pixels
# Average reprojection error on image 36 is 0.33739633133695 pixels
# Average reprojection error on image 7 is 0.1369497321712683 pixels
# Average reprojection error across all 30 resected images is 0.1866865398538318 pixels

# %%
### This cell visualizes the pointcloud
num_voxels = 200 #Set to 100 for faster visualization, 200 for higher resolution.
x, y, z = [], [], []
for pt3 in points3d_with_views:
    if abs(pt3.point3d[0][0]) + abs(pt3.point3d[0][1]) + abs(pt3.point3d[0][2]) < 100:
        x.append(pt3.point3d[0][0])
        y.append(pt3.point3d[0][1])
        z.append(pt3.point3d[0][2])
vpoints = list(zip(x,y,z))
vpoints = np.array(vpoints)
vpoints_df = pd.DataFrame(data=vpoints, index=[f"{i}" for i in range(vpoints.shape[0])], columns=["x", "y","z"])
cloud = pyntcloud.PyntCloud(vpoints_df)
cloud.add_structure('voxelgrid', n_x=num_voxels,n_y=num_voxels,n_z=num_voxels)
cloud.structures[f'V([{num_voxels}, {num_voxels}, {num_voxels}],[None, None, None],True)'].plot(d=3)
# Out:
#         <iframe
#             width="800"
#             height="500"
#             src="plotVG.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
